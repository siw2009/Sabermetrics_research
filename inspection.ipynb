# %%
import pandas as pd
df = pd.read_csv('./inputs/weatherAUS (testdata).csv')
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
df['RainToday'].isna().sum()
# Out:
# np.int64(3261)

# %%
df['RainTomorrow'].isna().sum()
# Out:
# np.int64(3267)

# %%
df_cleanna = df.dropna()
df_cleanna
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 6049    2009-01-01    Cobar     17.9     35.2       0.0         12.0
# 6050    2009-01-02    Cobar     18.4     28.9       0.0         14.8
# 6052    2009-01-04    Cobar     19.4     37.6       0.0         10.8
# 6053    2009-01-05    Cobar     21.9     38.4       0.0         11.4
# 6054    2009-01-06    Cobar     24.2     41.0       0.0         11.2
# ...            ...      ...      ...      ...       ...          ...
# 142298  2017-06-20   Darwin     19.3     33.4       0.0          6.0
# 142299  2017-06-21   Darwin     21.2     32.6       0.0          7.6
# 142300  2017-06-22   Darwin     20.7     32.8       0.0          5.6
# 142301  2017-06-23   Darwin     19.5     31.8       0.0          6.2
# 142302  2017-06-24   Darwin     20.2     31.7       0.0          5.6
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
df_cleanna['RainTomorrow'].isna().sum()
# Out:
# np.int64(0)

# %%
directions = set(df_cleanna['WindDir3pm']).union(set(df_cleanna['WindDir9am'])).union(set(df_cleanna['WindGustDir']))
directions
# Out:
# {'E',
#  'ENE',
#  'ESE',
#  'N',
#  'NE',
#  'NNE',
#  'NNW',
#  'NW',
#  'S',
#  'SE',
#  'SSE',
#  'SSW',
#  'SW',
#  'W',
#  'WNW',
#  'WSW'}

# %%
dir_labels = ['WindDir3pm', 'WindDir9am', 'WindGustDir']
dir_num = {'N': 0, 'NNE': 22.5, 'NE': 45, 'ENE': 67.5,
           'E': 90, 'ESE': 112.5, 'SE': 135, 'SSE': 157.5,
           'S': 180, 'SSW': 202.5, 'SW': 225, 'WSW': 247.5,
           'W': 270, 'WNW': 292.5, 'NW': 315, 'NNW': 337.5}

# %%
cnt = 0
for i, x in df_cleanna.iterrows():
    if any([x[l] not in dir_num for l in dir_labels]):
        print(i)
        cnt += 1

# %%
'N' in dir_num
# Out:
# True

# %%
'A' in dir_num
# Out:
# False

# %%
df_dir2num = df_cleanna.copy()
# for i,x in df_dir2num.iterrows():
#     for l in dir_labels:
#         # x[l] = dir_num[x[l]]
#         x[l] = 0

for l in dir_labels:
    df_dir2num[l] = df_dir2num[l].replace(dir_num)
# Out:
# C:\Users\siw20\AppData\Local\Temp\ipykernel_19768\335843237.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_dir2num[l] = df_dir2num[l].replace(dir_num)

# %%
df_dir2num
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 6049    2009-01-01    Cobar     17.9     35.2       0.0         12.0
# 6050    2009-01-02    Cobar     18.4     28.9       0.0         14.8
# 6052    2009-01-04    Cobar     19.4     37.6       0.0         10.8
# 6053    2009-01-05    Cobar     21.9     38.4       0.0         11.4
# 6054    2009-01-06    Cobar     24.2     41.0       0.0         11.2
# ...            ...      ...      ...      ...       ...          ...
# 142298  2017-06-20   Darwin     19.3     33.4       0.0          6.0
# 142299  2017-06-21   Darwin     21.2     32.6       0.0          7.6
# 142300  2017-06-22   Darwin     20.7     32.8       0.0          5.6
# 142301  2017-06-23   Darwin     19.5     31.8       0.0          6.2
# 142302  2017-06-24   Darwin     20.2     31.7       0.0          5.6
#
#         Sunshine  WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity9am  \
# ...

# %%
df_cleaned = df_dir2num.copy()
df_cleaned['RainToday'] = df_cleaned['RainToday'].replace({'Yes': 1, 'No': 0})
df_cleaned['RainTomorrow'] = df_cleaned['RainTomorrow'].replace({'Yes': 1, 'No': 0})
# Out:
# C:\Users\siw20\AppData\Local\Temp\ipykernel_19768\1951554839.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_cleaned['RainToday'] = df_cleaned['RainToday'].replace({'Yes': 1, 'No': 0})
# C:\Users\siw20\AppData\Local\Temp\ipykernel_19768\1951554839.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_cleaned['RainTomorrow'] = df_cleaned['RainTomorrow'].replace({'Yes': 1, 'No': 0})

# %%
df_cleaned
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 6049    2009-01-01    Cobar     17.9     35.2       0.0         12.0
# 6050    2009-01-02    Cobar     18.4     28.9       0.0         14.8
# 6052    2009-01-04    Cobar     19.4     37.6       0.0         10.8
# 6053    2009-01-05    Cobar     21.9     38.4       0.0         11.4
# 6054    2009-01-06    Cobar     24.2     41.0       0.0         11.2
# ...            ...      ...      ...      ...       ...          ...
# 142298  2017-06-20   Darwin     19.3     33.4       0.0          6.0
# 142299  2017-06-21   Darwin     21.2     32.6       0.0          7.6
# 142300  2017-06-22   Darwin     20.7     32.8       0.0          5.6
# 142301  2017-06-23   Darwin     19.5     31.8       0.0          6.2
# 142302  2017-06-24   Darwin     20.2     31.7       0.0          5.6
#
#         Sunshine  WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity9am  \
# ...

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56420 entries, 6049 to 142302
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           56420 non-null  object
#  1   Location       56420 non-null  object
#  2   MinTemp        56420 non-null  float64
#  3   MaxTemp        56420 non-null  float64
#  4   Rainfall       56420 non-null  float64
#  5   Evaporation    56420 non-null  float64
#  6   Sunshine       56420 non-null  float64
#  7   WindGustDir    56420 non-null  float64
#  8   WindGustSpeed  56420 non-null  float64
#  9   WindDir9am     56420 non-null  float64
#  10  WindDir3pm     56420 non-null  float64
#  11  WindSpeed9am   56420 non-null  float64
#  12  WindSpeed3pm   56420 non-null  float64
#  13  Humidity9am    56420 non-null  float64
#  14  Humidity3pm    56420 non-null  float64
#  15  Pressure9am    56420 non-null  float64
#  16  Pressure3pm    56420 non-null  float64
# ...

# %%
df_sydney = df_cleaned[df_cleaned['Location'] == 'Sydney']
df_sydney
# Out:
#              Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 31168  2010-10-20   Sydney     12.9     20.3       0.2          3.0      10.9
# 31169  2010-10-21   Sydney     13.3     21.5       0.0          6.6      11.0
# 31170  2010-10-22   Sydney     15.3     23.0       0.0          5.6      11.0
# 31174  2010-10-26   Sydney     12.9     26.7       0.2          3.8      12.1
# 31175  2010-10-27   Sydney     14.8     23.8       0.0          6.8       9.6
# ...           ...      ...      ...      ...       ...          ...       ...
# 33515  2017-06-21   Sydney      8.6     19.6       0.0          2.0       7.8
# 33516  2017-06-22   Sydney      9.3     19.2       0.0          2.0       9.2
# 33517  2017-06-23   Sydney      9.4     17.7       0.0          2.4       2.7
# 33518  2017-06-24   Sydney     10.1     19.3       0.0          1.4       9.3
# 33519  2017-06-25   Sydney      7.6     19.3       0.0          3.4       9.4
#
# ...

# %%
df_cleaned['Location'].value_counts()
# Out:
# Location
# Darwin              3062
# Perth               3025
# Brisbane            2953
# MelbourneAirport    2929
# PerthAirport        2913
# SydneyAirport       2870
# Watsonia            2730
# Mildura             2594
# MountGambier        2465
# NorfolkIsland       2464
# Cairns              2444
# Townsville          2419
# WaggaWagga          2416
# AliceSprings        2223
# Nuriootpa           2008
# Hobart              1939
# Moree               1913
# Melbourne           1898
# Portland            1863
# Woomera             1734
# Sydney              1690
# Sale                1678
# CoffsHarbour        1380
# Williamtown         1198
# Canberra            1078
# Cobar                534
# Name: count, dtype: int64

# %%
df['Location'].value_counts()
# Out:
# Location
# Canberra            3436
# Sydney              3344
# Adelaide            3193
# Darwin              3193
# Hobart              3193
# Perth               3193
# Melbourne           3193
# Brisbane            3193
# Albury              3040
# MountGinini         3040
# GoldCoast           3040
# Wollongong          3040
# MountGambier        3040
# Launceston          3040
# AliceSprings        3040
# Albany              3040
# Townsville          3040
# Bendigo             3040
# Cairns              3040
# Ballarat            3040
# Penrith             3039
# Newcastle           3039
# Tuggeranong         3039
# PerthAirport        3009
# Williamtown         3009
# Cobar               3009
# BadgerysCreek       3009
# SydneyAirport       3009
# Richmond            3009
# Moree               3009
# CoffsHarbour        3009
# NorfolkIsland       3009
# WaggaWagga          3009
# Witchcliffe         3009
# Watsonia            3009
# Dartmoor            3009
# ...

# %%
df_darwin = df_cleaned[df_cleaned['Location'] == 'Darwin']
df_darwin
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 139111  2008-07-01   Darwin     20.0     33.1       0.0          4.4
# 139112  2008-07-02   Darwin     19.4     32.4       0.0          6.0
# 139113  2008-07-03   Darwin     18.2     31.8       0.0          8.0
# 139114  2008-07-04   Darwin     17.3     30.7       0.0          7.0
# 139115  2008-07-05   Darwin     15.5     30.8       0.0          7.0
# ...            ...      ...      ...      ...       ...          ...
# 142298  2017-06-20   Darwin     19.3     33.4       0.0          6.0
# 142299  2017-06-21   Darwin     21.2     32.6       0.0          7.6
# 142300  2017-06-22   Darwin     20.7     32.8       0.0          5.6
# 142301  2017-06-23   Darwin     19.5     31.8       0.0          6.2
# 142302  2017-06-24   Darwin     20.2     31.7       0.0          5.6
#
#         Sunshine  WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity9am  \
# ...

# %%
df_darwin.to_csv('./inputs/darwin (testdata).csv')

# %%
df_darwin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3062 entries, 139111 to 142302
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           3062 non-null   object
#  1   Location       3062 non-null   object
#  2   MinTemp        3062 non-null   float64
#  3   MaxTemp        3062 non-null   float64
#  4   Rainfall       3062 non-null   float64
#  5   Evaporation    3062 non-null   float64
#  6   Sunshine       3062 non-null   float64
#  7   WindGustDir    3062 non-null   float64
#  8   WindGustSpeed  3062 non-null   float64
#  9   WindDir9am     3062 non-null   float64
#  10  WindDir3pm     3062 non-null   float64
#  11  WindSpeed9am   3062 non-null   float64
#  12  WindSpeed3pm   3062 non-null   float64
#  13  Humidity9am    3062 non-null   float64
#  14  Humidity3pm    3062 non-null   float64
#  15  Pressure9am    3062 non-null   float64
#  16  Pressure3pm    3062 non-null   float64
# ...
